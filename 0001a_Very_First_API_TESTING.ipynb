# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Abgabe:
# 1. Lege eine Person (z.B. deinen Sitznachbarn) als Testperson im API auf https://datahouse.pythonanywhere.com/api/Testperson/ mit dem Web- Formular an
# 2. Frage diese Person im Ipython Notebook aus dem REST - API mittels GET - REQUEST ab und gib sie mit einem print - Befehl aus
# 3. Analysiere die JSON - Darstellung des API und gib an, a) um welche JSON - Datenstruktur es sich laut https://json.org bei dieser Webseite handelt:
#  ![image.png](attachment:image.png)
#
#     b) Ergänze einen Screenshot der passenden Datenstrukturen ![image-3.png](attachment:image-3.png)
#
#     ... und c) begründe (ACHTUNG: es kann sich um eine Kombination mehrerer JSON - Datenstrukturen handeln.)
#
# 4. Lege eine weitere Person mittels post request an und gib die "response" mittels print - Befehl aus
# 5. Führe abschließend einen get - request auf das REST - API aus, erzeuge einen DataFrame aus der zurückgegebenen Liste und gib die ersten 25 Zeilen
# des DataFrame aus. Ergänze dazu als Markdown oder als Kommentar den zutreffenden "Timestamp"
#
# API:Application Programming Interface REST: Representational State Transfer, RestFUL, Dr. Roy Fielding
# #### Hinweis: Die Teilaufgaben 1 - 5 sollten im Notebook dokumentiert werden. Das Notebook enthält bereits einzelne Code - Bestandteile, die als Hilfestellung verwendet werden können, achte jedoch auf eine nachvollziehbare Struktur!

# %%
#%pip install requests
#%pip install pandas
import requests
import json 
import pandas as pd
url = 'https://datahouse.pythonanywhere.com/api/Testperson/'

# %%
import requests                                                     #Importierung aller Anfragen

url = 'https://datahouse.pythonanywhere.com/api/Testperson/'        # URL der API
response = requests.get(url)                                        # GET Anfrage and die API verschicken 
persons = response.json()                                           # Spezifische Abfrage nach meinen Nachbarns
for person in persons:
    if person['name'] == 'Elias Klein':
        print(person)
        break
# Out:
# {'id': 125, 'name': 'Elias Klein', 'alias': 'Der einzig wahre', 'rec_time': '2023-05-05T06:43:11.965200Z', 'pers_uuid': '0faae1a4-0bc9-43ee-8a77-0d08592011ff'}

# %%
import requests

r = requests.post('https://datahouse.pythonanywhere.com/api/Testperson/' , data={ "alias": "Der einzig wahre", "name": "Elias Klein",})

# %%
import requests

url = 'https://datahouse.pythonanywhere.com/api/Testperson/'
response = requests.get(url)

data = response.json()
import pandas as pd

df = pd.DataFrame(data)
print(df.head(25))
# Out:
#      id             name                         alias  \
# 0   125      Elias Klein              Der einzig wahre
# 1   124       Mert Demir               Bundespräsident
# 2   123            Kerem                           siu
# 3   122            Kerem                           siu
# 4   121       Mert Demir               Bundespräsident
# 5   120       Mert Demir               Bundespräsident
# 6   119            Kerem                           siu
# 7   118              SAP                            DF
# 8   117       Mert Demir               Bundespräsdient
# 9   116  Florian Simader                            FS
# 10  115          Kajetan                         Daddy
# 11  114           Fabian                            FD
# 12  113              SAP                          King
# 13  112      Elias Klein                            EK
# 14  111              SAP                          king
# 15  110          Kajetan                         Daddy
# 16  109              SAP                          King
# 17  108           Fabian                            DF
# 18  107          Kajetan                         Daddy
# 19  106     Apollo Creed                          king
# 20  105           chemie                        scheiß
# 21  104             Luis                         Luigi
# 22  103              SAP  Systeme Anwendungen Produkte
# 23  102              SAP                          King
# 24  101              SAP                          King
#
#                        rec_time                             pers_uuid
# 0   2023-05-05T06:43:11.965200Z  0faae1a4-0bc9-43ee-8a77-0d08592011ff
# 1   2023-05-05T06:42:39.734497Z  fa8d97ef-27af-4b8e-afa2-ff6cec3ff6f1
# 2   2023-05-05T06:37:52.137659Z  629ae925-e832-4c71-a00b-5f7b95f5dc62
# 3   2023-05-05T06:34:44.342000Z  9489c661-82ae-4667-9eb0-6c7dec0da38b
# 4   2023-04-14T08:30:19.851286Z  689794fd-6913-4715-87a9-b7bda5f16758
# 5   2023-04-14T08:30:18.319298Z  6c451023-47e1-41a1-8a25-f0d28c6dd642
# 6   2023-04-14T08:26:08.772312Z  06e22920-4b5b-4b74-b229-918d328958cf
# 7   2023-04-14T08:15:10.390736Z  02d8e642-8eeb-4422-8c4e-d0373cce9fd6
# 8   2023-04-14T07:44:42.495790Z  fa399acc-a50c-4f5d-ba2b-c3c4b8a9b62e
# 9   2023-04-14T07:43:44.823685Z  2075484f-cc3d-4915-a0ab-26964780e12a
# 10  2023-04-14T07:40:07.034792Z  60dbcd92-3329-4ca9-8861-f495539f7194
# 11  2023-04-14T07:39:13.143643Z  01240196-2404-4d1f-b1a4-3c5bf7b324ae
# 12  2023-04-14T07:36:49.483414Z  76ef2b9a-708e-4044-ad4b-9d650b2af43c
# 13  2023-04-14T07:34:04.633392Z  14ba230f-e31f-4e38-95fb-92219f9fa8ea
# 14  2023-04-14T07:33:25.575612Z  1e1346cd-8042-478d-a6ff-c553fae363a0
# 15  2023-04-14T07:32:38.110272Z  398042ae-00ec-4eab-b509-ea4c6d721e39
# 16  2023-04-14T07:31:32.538068Z  969fae39-97df-49c7-bec4-05d667f5d93f
# 17  2023-04-14T07:31:02.776326Z  dea74e3f-3f43-408a-80fa-491b00d42fe5
# 18  2023-04-14T07:29:39.288932Z  35b5eb43-2bc1-4c85-b14a-cc8dc9f62a9d
# 19  2023-04-14T07:28:55.925089Z  7a417aa4-6e77-419f-b5da-0f9eb5dd01e1
# 20  2023-04-14T07:28:48.278109Z  027b3ce0-ef5b-4a41-9480-f5a7e70a1907
# 21  2023-04-14T07:28:27.922421Z  d3cb8f75-f6d5-4daa-a1a6-adf0a7558ecc
# 22  2023-04-14T07:28:27.444392Z  f9915c48-0bd3-428d-ab3c-d6e82638d8c4
# 23  2023-04-14T07:28:12.537776Z  57cfe7fc-79f3-4cb9-9857-120037476f7e
# 24  2023-04-14T07:27:49.714862Z  8ffac7fc-5413-4760-b632-55bf5fede7f5

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
response = requests.get(url)
print(response)
testdata=response.json()
print(testdata)
print(response.raw)
print(response.text)
print(type(testdata))
# Out:
# <Response [200]>
# [{'name': 'Chris Hemsworth', 'alias': 'Thor'}, {'name': 'Steve Rogers', 'alias': 'Captain America'}]
# <urllib3.response.HTTPResponse object at 0x0000019B18136B90>
# [{"name":"Chris Hemsworth","alias":"Thor"},{"name":"Steve Rogers","alias":"Captain America"}]
# <class 'list'>

# %%
type(testdata)
df=pd.DataFrame(testdata)
print(df)
# Out:
#               name            alias
# 0  Chris Hemsworth             Thor
# 1     Steve Rogers  Captain America

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# post request trial 
response1 = requests.post(url,json={
    "name": "SAP",
    # ???? another columd is an additional key- value pair
})
